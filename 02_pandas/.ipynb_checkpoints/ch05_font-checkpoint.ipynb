# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=np.random.randint(-100,100,50).cumsum()

data
# Out:
# array([  53,  135,  101,  102,  129,   89,   14,  -17,   74,  144,  177,
#         127,   88,  102,  181,  183,  261,  270,  337,  396,  450,  459,
#         503,  538,  461,  461,  545,  578,  574,  479,  519,  502,  587,
#         645,  716,  676,  633,  573,  627,  666,  756,  759,  739,  773,
#         860,  935,  933,  881,  975, 1018])

# %%
data=np.random.randint(-100,100,50).cumsum()
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# 이렇게 출력하면 한글이깨짐
# Out:
# Text(0.5, 0, '시간(분)')

# %%
# 1.폰트파일로 FontProperties()
import matplotlib.font_manager as fm

path='D2CODING.TTC'
fontprop=fm.FontProperties(fname=path,size=14)

data=np.random.randint(-100,100,50).cumsum()
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이',fontproperties=fontprop)
plt.ylabel('주식가격',fontproperties=fontprop)
plt.xlabel('시간(분)',fontproperties=fontprop)
# Out:
# Text(0.5, 0, '시간(분)')

# %%
# 2.rcParams[]실행
# 기본폰트확인하기 
import matplotlib


print('설정파일위치:',matplotlib.matplotlib_fname())
print('기본설정폰트:',plt.rcParams['font.family'])
print('기본 폰트 크기 :',plt.rcParams['font.size'])
plt.rcParams['font.family']='Malgun Gothic'
plt.rcParams['font.size']=12
plt.rcParams['axes.unicode_minus']=False
print('기본설정폰트:',plt.rcParams['font.family'])
print('기본 폰트 크기 :',plt.rcParams['font.size'])
# Out:
# 설정파일위치: C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 기본설정폰트: ['NanumSquare Neo Light']
# 기본 폰트 크기 : 10.0
# 기본설정폰트: ['Malgun Gothic']
# 기본 폰트 크기 : 12.0

# %%
data=np.random.randint(-100,100,50).cumsum()
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
#3.설정파일에 세팅방법
print('설정파일위치:',matplotlib.matplotlib_fname())
[font.name for font in fm.fontManager.ttflist if 'Nanum' in font.name]
# Out:
# 설정파일위치: C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\mpl-data\matplotlibrc
# ['NanumSquare Neo Heavy',
#  'NanumSquare Neo Light',
#  'NanumSquare Neo Bold',
#  'NanumSquare Neo ExtraBold',
#  'NanumSquare Neo Regular']

# %%
import seaborn as sns
tips=sns.load_dataset('tips')

# %%
# sns.distplot(tips['total_bill'])
ax=sns.histplot(data=tips,x='total_bill',bins=8,kde=True)
ax.set_title('히스토그램')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # sns.distplot(tips['total_bill'])
#       2 sns.histplot(data=tips,x='total_bill',bins=8,kde=True)
# ----> 3 ax.set_title('히스토그램')
#
# NameError: name 'ax' is not defined

# %%
sns.__version__
# Out:
# '0.12.2'
