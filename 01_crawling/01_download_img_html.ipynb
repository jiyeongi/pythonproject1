# %% [markdown]
# # 1.이미지다운로드
# ## 01.urllib

# %%
from urllib import request

# %%
url ='https://allways.smotor.com/wp-content/uploads/2023/03/shutterstock_1919159690-1024x576.jpg'
savename='test.jpg'

# %%
request.urlretrieve(url,savename)
# Out:
# ('test.jpg', <http.client.HTTPMessage at 0x21336156c50>)

# %%
#02.html소스다운로드
##01.urllib

# %%
url= 'http://www.naver.com/'
request.urlopen(url).read().decode('utf8')
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %% [markdown]
# # 02. request이용

# %%
import requests

# %%
url= 'http://www.naver.com/'
r=requests.get(url)

# %%
type(r)
# Out:
# requests.models.Response

# %%
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'text/html; charset=UTF-8'

# %%
r.encoding
# Out:
# 'UTF-8'

# %%
r.text
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
r = requests.get('https://api.github.com/user', auth=('user', 'pass'))

# %%
r.text
# Out:
# '{"message":"Requires authentication","documentation_url":"https://docs.github.com/rest/reference/users#get-the-authenticated-user"}'

# %%
r.json()
# Out:
# {'message': 'Requires authentication',
#  'documentation_url': 'https://docs.github.com/rest/reference/users#get-the-authenticated-user'}

# %%
url = 'http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=f5eef3421c602c6cb7ea224104795888&targetDt=20120101'
r = requests.get(url)
r.json()
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#   'showRange': '20120101~20120101',
#   'dailyBoxOfficeList': [{'rnum': '1',
#     'rank': '1',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20112207',
#     'movieNm': '미션임파서블:고스트프로토콜',
#     'openDt': '2011-12-15',
#     'salesAmt': '2776060500',
#     'salesShare': '36.3',
#     'salesInten': '-415699000',
#     'salesChange': '-13',
#     'salesAcc': '40541108500',
#     'audiCnt': '353274',
#     'audiInten': '-60106',
#     'audiChange': '-14.5',
#     'audiAcc': '5328435',
#     'scrnCnt': '697',
#     'showCnt': '3223'},
#    {'rnum': '2',
#     'rank': '2',
#     'rankInten': '1',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20110295',
#     'movieNm': '마이 웨이',
#     'openDt': '2011-12-21',
#     'salesAmt': '1189058500',
#     'salesShare': '15.6',
#     'salesInten': '-105894500',
#     'salesChange': '-8.2',
#     'salesAcc': '13002897500',
#     'audiCnt': '153501',
# ...

# %% [markdown]
# ### 03.검색어 넣어서 html페이지 가져오기

# %%
# 쿼리스트링
'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzAzMTVfMjQ1%2FMDAxNjc4ODY1MDI4MjY5.36q52Vh2gmmKEwaCP57SckpzylS7XWjJqsfaDWgiRSgg.2r-jmZUSjePWSl_r0ThLdtaI7VSippPe4v0Px2tY0U4g.JPEG.bsgangseogu%2FJK9A0962_1.jpg%2FJK9A0962_1.jpg&type=a340'
# Out:
# 'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzAzMTJfMjE4%2FMDAxNjc4NTUzOTI5NjUy.TNwIGwqEDXuW3BYDgaTe2fl3gIGBsJH4_yde3IYtDygg.AQqB5clPbPs9c-ZBQhWUSNMDaD3vn-6pUjz5A_ydrg8g.JPEG.sjlim056%2FKakaoTalk_20230312_015750734.jpg&type=a340'

# %%
# 한글이 문제가됨 
from urllib import request,parse

# %%
from urllib import request

query = input('검색할 키 >>>')
url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query=' + query
print(url)
request.urlopen(url).read()
# Out:
# 검색할 키 >>> 벚꽃
# https://search.naver.com/search.naver?where=image&sm=tab_jum&query=벚꽃
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[1], line 6
#       4 url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query=' + query
#       5 print(url)
# ----> 6 request.urlopen(url).read()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
# ...

# %%
url = 'https//search.naver.com/search.naver?'
query=input('검색할키>>>')
values={
    # 'where':'image',
    # 'sm':'tab_jum',
    
    'query':query
}
params=parse.urlencode(values)
url= url+params
print(url)

request.urlopen(url).read().decode('utf8')
# Out:
# 검색할키>>> 벚꽃
# https//search.naver.com/search.naver?query=%EB%B2%9A%EA%BD%83
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 13
#      10 url= url+params
#      11 print(url)
# ---> 13 request.urlopen(url).read().decode('utf8')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:503, in OpenerDirector.open(self, fullurl, data, timeout)
#     500 def open(self, fullurl, data=None, timeout=socket._GLOBAL_DEFAULT_TIMEOUT):
#     501     # accept a URL or a Request object
#     502     if isinstance(fullurl, str):
# --> 503         req = Request(fullurl, data)
#     504     else:
# ...

# %% [markdown]
# #### 02.requests 이용

# %%
import requests

# %%
query= input('검색할 키 >>>')
url = 'https//search.naver.com/search.naver?'
values={
 'query':query   
}
r= requests.get(url,params=values)
r.text
# Out:
# 검색할 키 >>> 벚꽃
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[62], line 6
#       2 url = 'https//search.naver.com/search.naver?'
#       3 values={
#       4  'query':query
#       5 }
# ----> 6 r= requests.get(url,params=values)
#       7 r.text
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
# ...
