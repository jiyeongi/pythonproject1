# %%
Client_ID='5hTp14IHsImB3hzhjn_x'
Client_Secret='QQ7Ss68_hP'

# %%
# 네이버 api 예제- 블로그검색하기
import os
import sys
import urllib.request
import json

client_id = "5hTp14IHsImB3hzhjn_x"
client_secret = "QQ7Ss68_hP"
query=input("검색할단어")
encText = urllib.parse.quote("검색할 단어")

print(encText)

url = "https://openapi.naver.com/v1/search/blog?display=100&query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
    
data = response_body.decode('utf-8')
print(type(data))
# Out:
# 검색할단어 봄
# %EA%B2%80%EC%83%89%ED%95%A0%20%EB%8B%A8%EC%96%B4
# {
# 	"lastBuildDate":"Wed, 05 Apr 2023 11:32:48 +0900",
# 	"total":906304,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"03.28 화요일 선크림\/감정<b>단어<\/b>\/<b>검색<\/b>\/연습\/알리\/현백\/맡기기... ",
# 			"link":"https:\/\/blog.naver.com\/teetee777\/223058579521",
# 			"description":"감정의 <b>단어<\/b>가 더 많다는것도 알게됨 #선물<b>검색<\/b> 2주년 선물로 뭐가 좋을지 고민하다가 하나 아이템을 정해서 <b>검색<\/b>을 했더니 동선이 딱 맞아 떨어지는 곳에서 살 수 있게되어 기뻤다! #편지미리써놓기 #연습... ",
# 			"bloggername":"A lover of date",
# 			"bloggerlink":"blog.naver.com\/teetee777",
# 			"postdate":"20230329"
# 		},
# 		{
# 			"title":"아이폰 사파리 텍스트 찾기 <b>단어<\/b> <b>검색<\/b> 방법 정리",
# 			"link":"https:\/\/blog.naver.com\/jhbksgi\/222982804031",
# 			"description":"아이폰 사파리 크롬 텍스트 찾기 <b>단어<\/b> <b>검색<\/b> 방법 정리 글\/사진 : 곰T 기본적으로 컴퓨터용, 모바일용 Browser에는 '<b>검색<\/b>' 기능이 있습니다. 그냥 <b>검색<\/b>(Search)이라고 하면 감이 잘 오지 않을 수 있겠네요. 좀 더... ",
# 			"bloggername":"곰T의 IT트러블슈팅",
# ...

# %%
# 파일로되어있지않을때는load에 s를 붙여야함
result=json.loads(data)
print(type(result))
# Out:
# <class 'dict'>

# %%
for item in result['items'] :
    print(item['link'])
# Out:
# https://blog.naver.com/teetee777/223058579521
# https://blog.naver.com/jhbksgi/222982804031
# https://blog.naver.com/zenither/223041954219
# https://blog.naver.com/rhyrhyrhy/222923284547
# https://blog.naver.com/gsamo/222899718641
# https://blog.naver.com/etcsc469/223027975062
# https://blog.naver.com/tepet/222697272255
# https://blog.naver.com/codethem/222310806177
# https://blog.naver.com/parangbee/223045217974
# https://blog.naver.com/alkalifa/222972234445
# https://blog.naver.com/seejine/223005367423
# https://blog.naver.com/hi_kira/222853564187
# https://blog.naver.com/nbssd/222931719218
# https://blog.naver.com/tombyun/223046917415
# https://blog.naver.com/rightpdf/223059827451
# https://blog.naver.com/shell629/223017121925
# https://blog.naver.com/dmswl9028/222774697180
# https://blog.naver.com/synergieblog/222968926394
# https://blog.naver.com/salt7311/222840662771
# https://blog.naver.com/silluel/222947336035
# https://odydy311.tistory.com/2479
# ...

# %%
# 네이버 api 예제- 블로그검색하기
import os
import sys
import urllib.request
import json

client_id = "5hTp14IHsImB3hzhjn_x"
client_secret = "QQ7Ss68_hP"
query=input("검색할단어")
encText = urllib.parse.quote("검색할 단어")

print(encText)

url = "https://openapi.naver.com/v1/search/movie.json?display=100&query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

> GET /v1/search/movie.xml?query=%EC%A3%BC%EC%8B%9D&display=10&start=1&genre=1 HTTP/1.1
> Host: openapi.naver.com
> User-Agent: curl/7.49.1
> Accept: */*
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
    
data = response_body.decode('utf-8')
print(type(data))
